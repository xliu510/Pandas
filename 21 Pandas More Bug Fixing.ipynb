# %%
import pandas as pd
csv_path = "Week_04_Pandas_CSV_XLSX/EclipseBugs.csv"
eclipse_df = pd.read_csv(csv_path)
eclipse_df.head()
# Out:
#    Bug\nID Product Component Assignee    Status Resolution  \
# 0     3638     JDT        UI  aeschli  VERIFIED      FIXED
# 1     3854     JDT        UI  aeschli  VERIFIED      FIXED
# 2     4188     JDT        UI  aeschli  VERIFIED      FIXED
# 3     5115     JDT     Debug  aeschli  VERIFIED      FIXED
# 4     5820     JDT        UI  aeschli  VERIFIED      FIXED
#
#                                              Summary           Changed  \
# 0  Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1             Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                     type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3  Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4    Close all editors brings up hierarchy of object  11/20/2001 16:22
#
#   Assignee\nReal\nName Classification  ...  Number of\nComments  \
# 0   Martin Aeschlimann        Eclipse  ...                    3
# 1   Martin Aeschlimann        Eclipse  ...                    5
# 2   Martin Aeschlimann        Eclipse  ...                    3
# 3   Martin Aeschlimann        Eclipse  ...                   10
# 4   Martin Aeschlimann        Eclipse  ...                    5
#
#              Opened            OS Priority       Reporter  \
# 0  10/10/2001 22:58    Windows NT       P1        aeschli
# 1  10/10/2001 23:01    Windows NT       P1    david_audel
# 2  10/10/2001 23:07  Windows 2000       P1    erich_gamma
# 3  10/19/2001 13:41  Windows 2000       P1  darin.eclipse
# 4  11/12/2001 18:18  Windows 2000       P1   jed.anderson
#
#   Reporter\nReal\nName Severity Target\nMilestone Version Votes
# 0   Martin Aeschlimann    major               ---       2     0
# 1          David Audel   normal               ---       2     0
# 2          Erich Gamma   normal               ---       2     0
# 3         Darin Wright   normal               ---       2     0
# 4         Jed Anderson   normal               ---       2     0
#
# [5 rows x 21 columns]

# %%
# Get all the column names using .columns

eclipse_df.columns
# Out:
# Index(['Bug\nID', 'Product', 'Component', 'Assignee', 'Status', 'Resolution',
#        'Summary', 'Changed', 'Assignee\nReal\nName', 'Classification',
#        'Hardware', 'Number of\nComments', 'Opened', 'OS', 'Priority',
#        'Reporter', 'Reporter\nReal\nName', 'Severity', 'Target\nMilestone',
#        'Version', 'Votes'],
#       dtype='object')

# %%
# Remove newlines \n from column headers using .rename()
eclipse_df = eclipse_df.rename(columns = {"Bug\nID":"Bug ID",
                                          "Assignee\nReal\nName":"Assignee Real Name",
                                          "Number of\nComments":"Number of Comments",
                                         "Reporter\nReal\nName":"Reporter Real Name",
                                         "Target\nMilestone":"Target Milestone"})

eclipse_df.columns
# Out:
# Index(['Bug ID', 'Product', 'Component', 'Assignee', 'Status', 'Resolution',
#        'Summary', 'Changed', 'Assignee Real Name', 'Classification',
#        'Hardware', 'Number of Comments', 'Opened', 'OS', 'Priority',
#        'Reporter', 'Reporter Real Name', 'Severity', 'Target Milestone',
#        'Version', 'Votes'],
#       dtype='object')

# %%
# Finding the average number of comments per bug using .mean()

average_comments = eclipse_df["Number of Comments"].mean()
average_comments
# Out:
# 8.75

# %%
# Grouping the DataFrame by "Assignee" using .groupby("")

assignee_group = eclipse_df.groupby("Assignee")
assignee_group.head()
# Out:
#       Bug ID   Product                                 Component  \
# 0       3638       JDT                                        UI
# 1       3854       JDT                                        UI
# 2       4188       JDT                                        UI
# 3       5115       JDT                                     Debug
# 4       5820       JDT                                        UI
# 16    188521  Platform                           User Assistance
# 17      6341       JDT                                        UI
# 18      7046       JDT                                        UI
# 19      7317       JDT                                        UI
# 20      7639       JDT                                        UI
# 21      7873       JDT                                        UI
# 36    351426       JDT                                      Core
# 37      2854  Platform                                   Compare
# 38      6525       JDT                                        UI
# 39      6668       JDT                                        UI
# 40     13730  Platform                                   Compare
# 41     15294       JDT                                        UI
# 51    429301  Platform                                       SWT
# 52    151683       JDT                                        UI
# 53     15983  Platform                           User Assistance
# 54     66801  Platform  Update  (deprecated - use RT>Equinox>p2)
# 55    120582  Platform                                        UI
# 56    121939  Platform                                        UI
# 57    123375  Platform                                        UI
# 58    126839  Platform                                        UI
# 59    134727  Platform                                        UI
# 69      7028  Platform                                       SWT
# 70     15575  Platform                                       SWT
# 71     92704  Platform                                     Debug
# 72    136223  Platform                                     Debug
# ...      ...       ...                                       ...
# 6639   54605       PDE                                        UI
# 6640   59249       PDE                                        UI
# 6641   60751       PDE                                        UI
# 6642   61651       PDE                                        UI
# 6655   41673       JDT                                     Debug
# 6661  308035  Platform                           User Assistance
# 6662  344446  Platform                           User Assistance
# 6663  365986  Platform                           User Assistance
# 6664  415522  Platform                                        UI
# 6665  419435  Platform                                        UI
# 6666  423882  Platform                                        UI
# 6667  432480  Platform                                        UI
# 6668  435698       PDE                                        UI
# 6678   45453  Platform                                       SWT
# 6679  416475  Platform                           User Assistance
# 6680  417447  Platform                                        UI
# 6681  436247  Platform                                        UI
# 7509   67028  Platform                                        UI
# 7510  119617  Platform                                        UI
# 7511  120748  Platform                           User Assistance
# 7512  126267  Platform                           User Assistance
# 7518  153461  Platform                                     Debug
# 7519  188184       PDE                                        UI
# 7520  204924       PDE                                        UI
# 7521  260802  Platform                                     Debug
# 7522  386866       PDE                                        UI
# 8255  457390  Platform                                        UI
# 8256  482155       PDE                                        UI
# 8257  471310  Platform                                        UI
# 8258  484292  Platform                                       SWT
#
#                       Assignee    Status  Resolution  \
# 0                      aeschli  VERIFIED       FIXED
# 1                      aeschli  VERIFIED       FIXED
# 2                      aeschli  VERIFIED       FIXED
# 3                      aeschli  VERIFIED       FIXED
# 4                      aeschli  VERIFIED       FIXED
# 16                    agarcher  VERIFIED       FIXED
# 17                     akiezun  VERIFIED       FIXED
# 18                     akiezun  VERIFIED       FIXED
# 19                     akiezun  VERIFIED       FIXED
# 20                     akiezun  VERIFIED       FIXED
# 21                     akiezun  VERIFIED       FIXED
# 36                  amj87.iitr  VERIFIED       FIXED
# 37               andre_weinand  VERIFIED       FIXED
# 38               andre_weinand  VERIFIED       FIXED
# 39               andre_weinand  VERIFIED       FIXED
# 40               andre_weinand  VERIFIED       FIXED
# 41               andre_weinand  VERIFIED       FIXED
# 51          arunkumar.thondapu  VERIFIED       FIXED
# 52           benno.baumgartner  VERIFIED       FIXED
# 53                      birsan  VERIFIED  WORKSFORME
# 54                      birsan  VERIFIED       FIXED
# 55                    bokowski  VERIFIED       FIXED
# 56                    bokowski  VERIFIED       FIXED
# 57                    bokowski  VERIFIED       FIXED
# 58                    bokowski  VERIFIED       FIXED
# 59                    bokowski  VERIFIED       FIXED
# 69             carolynmacleod4  VERIFIED       FIXED
# 70             carolynmacleod4  VERIFIED       FIXED
# 71                     chanskw  VERIFIED       FIXED
# 72                     chanskw  VERIFIED       FIXED
# ...                        ...       ...         ...
# 6639               cherie.wong  VERIFIED       FIXED
# 6640               cherie.wong  VERIFIED       FIXED
# 6641               cherie.wong  VERIFIED       FIXED
# 6642               cherie.wong  VERIFIED       FIXED
# 6655                     chris  VERIFIED       FIXED
# 6661               ChrisAustin  VERIFIED       FIXED
# 6662               ChrisAustin  VERIFIED       FIXED
# 6663               ChrisAustin  VERIFIED       FIXED
# 6664          christian.georgi  VERIFIED       FIXED
# 6665          christian.georgi  VERIFIED       FIXED
# 6666          christian.georgi  VERIFIED       FIXED
# 6667          christian.georgi  VERIFIED       FIXED
# 6668          christian.georgi  VERIFIED       FIXED
# 6678  christophe.cornu+eclipse  VERIFIED       FIXED
# 6679                   cizbasa  VERIFIED       FIXED
# 6680                   cizbasa  VERIFIED       FIXED
# 6681                   cizbasa  VERIFIED       FIXED
# 7509                   cturner  VERIFIED       FIXED
# 7510                  curtispd  VERIFIED       FIXED
# 7511                  curtispd  VERIFIED       FIXED
# 7512                  curtispd  VERIFIED       FIXED
# 7518            Curtis_Windatt  VERIFIED       FIXED
# 7519            Curtis_Windatt  VERIFIED       FIXED
# 7520            Curtis_Windatt  VERIFIED       FIXED
# 7521            Curtis_Windatt  VERIFIED       FIXED
# 7522            Curtis_Windatt  VERIFIED       FIXED
# 8255                  d.zygann  VERIFIED       FIXED
# 8256                  d.zygann  VERIFIED       FIXED
# 8257           daniel.kruegler  VERIFIED       FIXED
# 8258           daniel.kruegler  VERIFIED       FIXED
#
#                                                 Summary           Changed  \
# 0     Package Viewer: order resource folders before ...    1/17/2002 7:28
# 1                Wrong execution's classpath. (1GEY0W0)    1/18/2002 4:02
# 2                        type hierachy - typo (1GJW2XJ)    1/28/2002 3:12
# 3     Workspace source locator fails with mulitple p...  11/13/2001 10:11
# 4       Close all editors brings up hierarchy of object  11/20/2001 16:22
# 16    [Webapp] Test F1: 2)  Standalone infocenter no...    6/11/2007 9:50
# 17                 NullPointerException from ReorgGroup    1/16/2002 2:31
# 18    NPE trying to show context menu on method in O...    1/15/2002 6:14
# 19                       ClassCastException during move    1/15/2002 5:53
# 20                   NPE when renaming a local variable    2/13/2002 8:29
# 21                                 Bogus error messages    3/28/2002 5:22
# 36    [1.7][code assist] CompletionContext.getExpect...     8/2/2011 9:01
# 37        Compare: Save code path problematic (1GJYGAX)   5/14/2002 19:35
# 38    wrong indent when using replace from local his...    1/16/2002 3:43
# 39    'Replace from History' doesn't use source rang...    1/16/2002 4:36
# 40    Entire zipfiles content sent prior when comput...    6/13/2002 4:57
# 41       Deleting an open unsaved resource causes error     6/3/2002 5:16
# 51    Workspace selection screen broken in N20140228...     3/3/2014 5:14
# 52    [extract superclass] Extract Superclass withou...   5/15/2008 11:02
# 53               clicking on white space collapses tree   5/15/2002 15:47
# 54    "Reconciling" an installation with multiple ve...   6/21/2004 21:41
# 55    [DataBinding] Current validators mix data type...   2/16/2006 12:38
# 56    [Viewers] TreeSelection should subclass Struct...   2/14/2006 16:40
# 57    [DataBinding] Enhancements to the data binding...   2/14/2006 17:21
# 58                [DataBinding] IObservable refactoring    6/2/2006 15:22
# 59    [WorkbenchParts] Double save prompt with view ...   5/15/2006 14:05
# 69    ArrayIndexOutOfBoundsException by org.eclipse....   4/16/2002 22:22
# 70          Tree with checkbox items are not accessible    7/3/2002 13:10
# 71              Classcast exception from Registers View   4/26/2005 10:56
# 72    Suspended thread does not show stackframe/miss...    5/4/2006 13:00
# ...                                                 ...               ...
# 6639  Event Details dialog could be improved through...   4/10/2004 18:00
# 6640  Need to get back the "1 wizard to n extension-...   5/10/2004 14:05
# 6641  [Site Editor] UI still thinks it's on source p...   5/17/2004 17:39
# 6642  ClassCastException opening feature.xml from re...   5/11/2004 10:23
# 6655  Adding breakpoint in unsaved java file leads t...  11/24/2003 16:57
# 6661  [Help] Help Contents gets "Connection Refused"...    5/11/2015 8:34
# 6662     [Intro] BIDI: BDL_Welcome page is not mirrored   5/16/2011 13:22
# 6663                  Compile warning in official build   12/14/2011 2:39
# 6664  [IDE] Clean dialog should scroll to reveal sel...    5/31/2014 4:06
# 6665  [Themes] Invalid RGB color value in themes ext...     6/4/2014 8:11
# 6666  [IDE] Workspace version check should warn if w...     8/7/2014 6:08
# 6667  [Workbench] [Preferences] Preferences -> Gener...    1/30/2015 8:03
# 6668         NPE in Tracing UI if started w/o workspace   8/29/2014 14:13
# 6678      pocketpc - Pop-Up menus do not work on Tables  11/11/2003 15:06
# 6679  An empty focus is present at the Cheetsheets s...   5/30/2014 11:25
# 6680  [PropertiesView] NPE in org.eclipse.ui.views.p...   4/28/2015 10:47
# 6681  [Themes] "Colors and Fonts" pref page fails wi...    8/28/2014 2:52
# 7509  [Workbench] Window > Show View should be disab...   6/13/2005 17:08
# 7510         [Wizards] Missing icon in New Class wizard   2/16/2006 16:34
# 7511  [Intro] "Browse source code" link doesn't do a...   5/30/2006 10:26
# 7512  Insert-at-anchor should insert elements, not j...    3/5/2006 14:56
# 7518                      DnD slow in breakpoints view.    7/29/2007 9:20
# 7519  [Preferences][Target] Allow multi-select for e...  10/29/2007 17:06
# 7520  Execution Environment select does not make sen...  10/24/2007 11:48
# 7521  Retargetable debug actions do not enable when ...   1/27/2009 10:48
# 7522  WSW38 TVT Possible non-externalized strings - ...    8/16/2012 3:05
# 8255                [FastView] Deprecated Fast View API   3/16/2015 19:55
# 8256  [PDEMultiPageContentOutline] Remove use of dep...    12/9/2015 0:47
# 8257  [Jobs] Property IProgressConstants2.SHOW_IN_TA...   3/16/2016 11:41
# 8258     [Win32] RGBA hashCode looses alpha information    1/25/2016 3:28
#
#       Assignee Real Name Classification  ...  Number of Comments  \
# 0     Martin Aeschlimann        Eclipse  ...                   3
# 1     Martin Aeschlimann        Eclipse  ...                   5
# 2     Martin Aeschlimann        Eclipse  ...                   3
# 3     Martin Aeschlimann        Eclipse  ...                  10
# 4     Martin Aeschlimann        Eclipse  ...                   5
# 16           Adam Archer        Eclipse  ...                  15
# 17           Adam Kiezun        Eclipse  ...                   2
# 18           Adam Kiezun        Eclipse  ...                   2
# 19           Adam Kiezun        Eclipse  ...                   2
# 20           Adam Kiezun        Eclipse  ...                   3
# 21           Adam Kiezun        Eclipse  ...                   5
# 36         Ayushman Jain        Eclipse  ...                  12
# 37         Andre Weinand        Eclipse  ...                   3
# 38         Andre Weinand        Eclipse  ...                   2
# 39         Andre Weinand        Eclipse  ...                   2
# 40         Andre Weinand        Eclipse  ...                   9
# 41         Andre Weinand        Eclipse  ...                   7
# 51         Arun Thondapu        Eclipse  ...                  10
# 52     Benno Baumgartner        Eclipse  ...                  11
# 53         Dorian Birsan        Eclipse  ...                   3
# 54         Dorian Birsan        Eclipse  ...                  12
# 55        Boris Bokowski        Eclipse  ...                  16
# 56        Boris Bokowski        Eclipse  ...                   5
# 57        Boris Bokowski        Eclipse  ...                  19
# 58        Boris Bokowski        Eclipse  ...                   7
# 59        Boris Bokowski        Eclipse  ...                  14
# 69       Carolyn MacLeod        Eclipse  ...                  10
# 70       Carolyn MacLeod        Eclipse  ...                   6
# 71         Samantha Chan        Eclipse  ...                   5
# 72         Samantha Chan        Eclipse  ...                  26
# ...                  ...            ...  ...                 ...
# 6639         Cherie Wong        Eclipse  ...                   6
# 6640         Cherie Wong        Eclipse  ...                  11
# 6641         Cherie Wong        Eclipse  ...                   4
# 6642         Cherie Wong        Eclipse  ...                   4
# 6655          Chris Tilt        Eclipse  ...                   7
# 6661        Chris Austin        Eclipse  ...                  22
# 6662        Chris Austin        Eclipse  ...                   7
# 6663        Chris Austin        Eclipse  ...                   4
# 6664    Christian Georgi        Eclipse  ...                  16
# 6665    Christian Georgi        Eclipse  ...                   5
# 6666    Christian Georgi        Eclipse  ...                   7
# 6667    Christian Georgi        Eclipse  ...                  22
# 6668    Christian Georgi        Eclipse  ...                   7
# 6678    Christophe Cornu        Eclipse  ...                  12
# 6679       Cornel Izbasa        Eclipse  ...                   4
# 6680       Cornel Izbasa        Eclipse  ...                   6
# 6681       Cornel Izbasa        Eclipse  ...                   4
# 7509         Cory Turner        Eclipse  ...                   4
# 7510  Curtis d'Entremont        Eclipse  ...                  15
# 7511  Curtis d'Entremont        Eclipse  ...                   6
# 7512  Curtis d'Entremont        Eclipse  ...                   7
# 7518      Curtis Windatt        Eclipse  ...                   5
# 7519      Curtis Windatt        Eclipse  ...                   5
# 7520      Curtis Windatt        Eclipse  ...                   8
# 7521      Curtis Windatt        Eclipse  ...                   4
# 7522      Curtis Windatt        Eclipse  ...                   6
# 8255        Denis Zygann        Eclipse  ...                   9
# 8256        Denis Zygann        Eclipse  ...                   6
# 8257     Daniel Kruegler        Eclipse  ...                  11
# 8258     Daniel Kruegler        Eclipse  ...                   6
#
#                 Opened                          OS Priority  \
# 0     10/10/2001 22:58                  Windows NT       P1
# 1     10/10/2001 23:01                  Windows NT       P1
# 2     10/10/2001 23:07                Windows 2000       P1
# 3     10/19/2001 13:41                Windows 2000       P1
# 4     11/12/2001 18:18                Windows 2000       P1
# 16     5/22/2007 20:12                         All       P1
# 17     11/27/2001 5:58                Windows 2000       P1
# 18    12/18/2001 10:49                       other       P1
# 19      1/7/2002 14:05                Windows 2000       P1
# 20     1/15/2002 14:44                Windows 2000       P1
# 21     1/17/2002 17:37                  Windows NT       P1
# 36       7/7/2011 7:38                         All       P1
# 37    10/10/2001 22:44                Windows 2000       P1
# 38     12/3/2001 18:19                Windows 2000       P1
# 39      12/7/2001 5:30                         All       P1
# 40     4/12/2002 18:16                Windows 2000       P1
# 41      5/5/2002 20:26                       other       P1
# 51      2/28/2014 5:22                       Linux       P1
# 52      7/25/2006 8:28                  Windows XP       P1
# 53     5/14/2002 17:43                       other       P1
# 54     6/11/2004 17:52                  Windows XP       P1
# 55    12/13/2005 10:25                         All       P1
# 56    12/22/2005 17:10                  Windows XP       P1
# 57     1/10/2006 23:18                  Windows XP       P1
# 58      2/7/2006 18:09                  Windows XP       P1
# 59       4/4/2006 8:26                  Windows XP       P1
# 69     12/18/2001 5:23                Windows 2000       P1
# 70      5/8/2002 15:11                Windows 2000       P1
# 71     4/25/2005 18:22                Windows 2000       P1
# 72     4/11/2006 19:18                  Windows XP       P1
# ...                ...                         ...      ...
# 6639    3/12/2004 7:39                         All       P3
# 6640    4/20/2004 9:56                  Windows XP       P3
# 6641     5/3/2004 9:58                  Windows XP       P3
# 6642   5/10/2004 15:45                Windows 2000       P3
# 6655    8/19/2003 7:30                  Windows NT       P3
# 6661    4/3/2010 15:11                  Windows XP       P3
# 6662     5/2/2011 8:58                  Windows XP       P3
# 6663    12/8/2011 2:15                         All       P3
# 6664   8/20/2013 15:46                   Windows 7       P3
# 6665   10/15/2013 5:32                         All       P3
# 6666   12/12/2013 4:52                         All       P3
# 6667    4/10/2014 2:35                         All       P3
# 6668   5/24/2014 11:18                         All       P3
# 6678  10/23/2003 12:21                  Windows CE       P3
# 6679    9/3/2013 16:26                   Windows 7       P3
# 6680   9/17/2013 13:36                         All       P3
# 6681   5/30/2014 11:06                   Windows 7       P3
# 7509   6/14/2004 12:44                  Windows XP       P3
# 7510    12/7/2005 7:17                  Windows XP       P3
# 7511  12/13/2005 16:26                  Windows XP       P3
# 7512    2/2/2006 16:21                  Windows XP       P3
# 7518   8/10/2006 12:12  Mac OS X - Carbon (unsup.)       P3
# 7519   5/21/2007 19:51                  Windows XP       P3
# 7520   9/28/2007 12:03                  Windows XP       P3
# 7521   1/12/2009 22:49                       Linux       P3
# 7522    8/8/2012 13:25                         All       P3
# 8255   1/13/2015 18:09                       Linux       P3
# 8256  11/13/2015 14:43                         All       P3
# 8257    6/29/2015 7:39                   Windows 7       P3
# 8258   12/14/2015 3:45                   Windows 7       P3
#
#                Reporter  Reporter Real Name     Severity Target Milestone  \
# 0               aeschli  Martin Aeschlimann        major              ---
# 1           david_audel         David Audel       normal              ---
# 2           erich_gamma         Erich Gamma       normal              ---
# 3         darin.eclipse        Darin Wright       normal              ---
# 4          jed.anderson        Jed Anderson       normal              ---
# 16              mpawlow      Mike Pawlowski       normal          3.3 RC2
# 17              aeschli  Martin Aeschlimann       normal              ---
# 18              eclipse     Joe Szurszewski       normal              ---
# 19             fraenkel    Michael Fraenkel       normal              ---
# 20         Ian_Petersen        Ian Petersen       normal              ---
# 21           lynne_kues          Lynne Kues       normal              ---
# 36        daniel_megert         Dani Megert       normal            3.7.1
# 37          James_Moody         James Moody       normal           2.0 M2
# 38          erich_gamma         Erich Gamma       normal              ---
# 39        andre_weinand       Andre Weinand       normal              ---
# 40       philippe_mulet       Philipe Mulet     critical           2.0 F3
# 41             srutledg      Scott Rutledge       normal           2.0 F2
# 51           Lars.Vogel          Lars Vogel      blocker           4.4 M6
# 52    benno.baumgartner   Benno Baumgartner        major          3.3 RC2
# 53         Dave_Thomson        Dave Thomson       normal              ---
# 54               birsan       Dorian Birsan      blocker          3.0 RC3
# 55                  djo           Dave Orme       normal           3.2 M5
# 56             bokowski      Boris Bokowski      blocker           3.2 M5
# 57               sxenos        Stefan Xenos       normal           3.2 M5
# 58             bokowski      Boris Bokowski       normal           3.2 M6
# 59              dsnoddy       Daniel Snoddy       normal          3.2 RC4
# 69               saitoh       Masaki Saitoh     critical              ---
# 70             omosaiye                Sola        major              ---
# 71              chanskw       Samantha Chan        major           3.1 M7
# 72              chanskw       Samantha Chan       normal          3.2 RC3
# ...                 ...                 ...          ...              ...
# 6639            sdavids    Sebastian Davids       normal           3.0 M8
# 6640            fplante     Frederic Plante      blocker           3.0 M9
# 6641        cherie.wong         Cherie Wong        major           3.0 M9
# 6642         nick_edgar          Nick Edgar       normal           3.0 M9
# 6655    steffen.schwark     Steffen Schwark       normal           3.0 M6
# 6661   davidmichaelkarr       David M. Karr       normal           4.4 M7
# 6662              bamir                amir       normal          3.7 RC1
# 6663      daniel_megert         Dani Megert        minor           3.8 M5
# 6664           cwindatt      Curtis Windatt       normal           4.4 M4
# 6665   christian.georgi    Christian Georgi       normal           4.4 M3
# 6666   christian.georgi    Christian Georgi       normal           4.4 M7
# 6667        paul.verest         Paul Verest  enhancement           4.5 M5
# 6668   christian.georgi    Christian Georgi       normal            4.4.1
# 6678        javasoupman        Nuno Pereira     critical              ---
# 6679      alokmanjrekar      ALOK MANJREKAR       normal           4.4 M5
# 6680                bsd      Brian de Alwis       normal           4.5 M7
# 6681     wojciech.sudol      Wojciech Sudol       normal            4.4.1
# 7509      daniel_megert         Dani Megert        minor              3.1
# 7510      daniel_megert         Dani Megert       normal           3.2 M5
# 7511           curtispd  Curtis d'Entremont       normal          3.2 RC6
# 7512           khalsted        Kari Halsted       normal           3.2 M5
# 7518         cocoakevin        Kevin Barnes       normal           3.3 M4
# 7519           mjboyers     Mike Boyersmith  enhancement           3.4 M3
# 7520           baumanbr        Brian Bauman       normal           3.4 M3
# 7521      pawel.1.piech         Pawel Piech        minor           3.5 M5
# 7522           matalbot      Matthew Talbot       normal            3.8.1
# 8255         Lars.Vogel          Lars Vogel       normal           4.5 M6
# 8256           d.zygann        Denis Zygann       normal           4.6 M4
# 8257    daniel.kruegler     Daniel Kruegler        minor           4.6 M6
# 8258    daniel.kruegler     Daniel Kruegler       normal           4.6 M5
#
#      Version Votes
# 0          2     0
# 1          2     0
# 2          2     0
# 3          2     0
# 4          2     0
# 16       3.3     0
# 17         2     0
# 18         2     0
# 19         2     0
# 20         2     0
# 21         2     0
# 36       3.7     0
# 37         2     0
# 38         2     0
# 39         2     0
# 40         2     0
# 41         2     0
# 51       4.4     0
# 52       3.2     0
# 53         2     0
# 54         3     0
# 55       3.2     0
# 56       3.2     0
# 57       3.2     0
# 58       3.2     0
# 59       3.2     0
# 69         1     0
# 70         2     0
# 71       3.1     0
# 72       3.2     0
# ...      ...   ...
# 6639       3     0
# 6640       3     0
# 6641       3     0
# 6642       3     0
# 6655   2.1.1     0
# 6661   3.5.2     1
# 6662     3.7     0
# 6663     3.8     0
# 6664     4.3     0
# 6665     4.3     0
# 6666   4.3.1     0
# 6667     4.4     0
# 6668     4.4     0
# 6678       3     0
# 6679   4.2.2     0
# 6680   4.3.1     1
# 6681     4.4     0
# 7509       3     0
# 7510     3.1     0
# 7511     3.2     0
# 7512     3.2     0
# 7518     3.2     0
# 7519     3.3     0
# 7520     3.4     0
# 7521     3.5     0
# 7522     3.8     0
# 8255     4.5     0
# 8256     4.6     0
# 8257     4.5     0
# 8258   4.5.1     0
#
# [718 rows x 21 columns]

# %%
# Count how many of each component Assignees worked on and create DataFrame of the data
# using .value_counts()

assignee_work = pd.DataFrame(assignee_group["Component"].value_counts())
assignee_work.head()
# Out:
#                                 Component
# Assignee       Component
# Aaron_Ferguson UI                      10
# Adam_Schlegel  UI                       7
# ChrisAustin    User Assistance          3
# Claude_Knaus   UI                      31
#                Text                     7

# %%
# Find the percentage of bugs overall fixed by each Assignee

total_bugs = eclipse_df["Assignee"].count()
bugs_per_user = assignee_group["Assignee"].count()

user_bug_percent = pd.DataFrame((bugs_per_user/total_bugs)*100)
user_bug_percent.head()
# Out:
#                 Assignee
# Assignee
# Aaron_Ferguson      0.10
# Adam_Schlegel       0.07
# ChrisAustin         0.03
# Claude_Knaus        0.38
# Curtis_Windatt      0.06

# %%
# Reset the index of "assignee_group" so that "Assignee" and "Component" are columns
# using .reset_index()

assignee_work = assignee_work.reset_index()
assignee_work.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-41ce5893b404> in <module>()
#       2 # using .reset_index()
#       3
# ----> 4 assignee_work = assignee_work.reset_index()
#       5 assignee_work.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4134                 # to ndarray and maybe infer different dtype
#    4135                 level_values = _maybe_casted_values(lev, lab)
# -> 4136                 new_obj.insert(0, name, level_values)
#    4137
#    4138         new_obj.index = new_index
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3217         value = self._sanitize_column(column, value, broadcast=False)
#    3218         self._data.insert(loc, column, value,
# -> 3219                           allow_duplicates=allow_duplicates)
#    3220
#    3221     def assign(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    4336         if not allow_duplicates and item in self.items:
#    4337             # Should this be a different kind of error??
# -> 4338             raise ValueError('cannot insert {}, already exists'.format(item))
#    4339
#    4340         if not isinstance(loc, int):
#
# ValueError: cannot insert Component, already exists
